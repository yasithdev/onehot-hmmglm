# %% [markdown]
# # HMM-GLM on the CRCRS pfc-6 Dataset

# %% [markdown]
# ## 1 Load the dataset

# %%
# %pip install -q --force-reinstall airavata-python-sdk[notebook]
import airavata_jupyter_magic

# %authenticate
# %request_runtime hpc_cpu --file=cybershuttle.yml --walltime=60 --use=NeuroData25VC1:cloud,expanse:shared,anvil:shared
# %switch_runtime hpc_cpu
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyopenssl 23.2.0 requires cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0, but you have cryptography 44.0.2 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
#
# Loaded airavata_jupyter_magic (2.0.9)
# (current runtime = local)
#
#   %authenticate                      -- Authenticate to access high-performance runtimes.
#   %request_runtime <rt> [args]       -- Request a runtime named <rt> with configuration <args>. Call multiple times to request multiple runtimes.
#   %restart_runtime <rt>              -- Restart runtime <rt>. Run this if you install new dependencies or if the runtime hangs.
#   %stop_runtime <rt>                 -- Stop runtime <rt> when no longer needed.
#   %switch_runtime <rt>               -- Switch active runtime to <rt>. All subsequent executions will use this runtime.
#   %%run_on <rt>                      -- Force a cell to always execute on <rt>, regardless of the active runtime.
#   %stat_runtime <rt>                 -- Show the status of runtime <rt>.
#   %copy_data <r1:file1> <r2:file2>   -- Copy <file1> in <r1> to <file2> in <r2>.
# Output()
# Authenticated.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Requesting runtime=hpc_cpu
# cpuCount: 4
# experimentName: CS_Agent
# group: Default
# libraries:
# - python=3.10
# - pip
# - ipywidgets
# memory: 4096
# mounts:
# - brainml-onehot-hmmglm:/cybershuttle_data/brainml-onehot-hmmglm
# nodeCount: 1
# pip:
# - git+https://github.com/cyber-shuttle/onehot-hmmglm#subdirectory=hmmglm
# queue: cloud
# remoteCluster: NeuroData25VC1
# wallTime: 60
#
# Requested runtime=hpc_cpu. state=CONFIGURING_WORKSPACE
# Switched to runtime=hpc_cpu.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Wedge
import pandas as pd
import torch
from torch import nn
from torch.nn import functional as F
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

from hmmglm.models import naive, onehot
from hmmglm import distributions, inference, utils
# Out:
# ⠦ Connecting to=hpc_cpu... status=CONNECTEDWORKSPACE

# %%
def load_data(dt: float = 20, T: float = 15000):
    n_time_bins = int(T / dt)
    session = "200104"
    behavior = pd.read_csv(
        f"/cybershuttle_data/brainml-onehot-hmmglm/{session}/{session}_Behavior.dat",
        sep="\t",
        header=None,
    )
    behavior.columns = [
        "trial_start_time",
        "trial_end_time",
        "rule",
        "outcome",
        "choice",
        "light_position",
    ]
    behavior.replace(
        {
            "rule": {
                1: "go right",
                2: "go light",
                3: "go left",
                4: "go dark",
            },
            "outcome": {1: "correct", 0: "incorrect"},
            "choice": {1: "left", 0: "right"},
            "light_position": {1: "left", 0: "right"},
        },
        inplace=True,
    )

    raw_position = pd.read_table(
        f"/cybershuttle_data/brainml-onehot-hmmglm/{session}/{session}_Pos.dat", header=None
    )
    raw_position.columns = ["time", "x", "y"]
    raw_spike_data = pd.read_table(
        f"/cybershuttle_data/brainml-onehot-hmmglm/{session}/{session}_SpikeData.dat", header=None
    )
    raw_spike_data.columns = ["time", "cell_id"]

    spike_time_by_cell_id = [
        (neuron, i["time"].values)
        for neuron, i in raw_spike_data.groupby("cell_id")
    ]
    n_neurons = len(spike_time_by_cell_id)
    n_trials = len(behavior)

    start_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_start_time"] - 5000
    )
    end_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_start_time"] - 5000 + T
    )
    trial_start_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_start_time"]
    )
    trial_end_idx_list = np.searchsorted(
        raw_position["time"], behavior["trial_end_time"]
    )

    behavior["trajectory"] = None
    behavior["trial_start_position"] = None
    behavior["trial_end_position"] = None
    spikes = torch.zeros((n_trials, n_time_bins, n_neurons))
    for trial in range(n_trials):
        time_bins = np.linspace(
            behavior.at[trial, "trial_start_time"] - 5000,
            behavior.at[trial, "trial_start_time"] - 5000 + T,
            n_time_bins + 1,
        )
        for neuron in range(n_neurons):
            spikes[trial, :, neuron] = torch.tensor(
                np.histogram(
                    spike_time_by_cell_id[neuron][1],
                    bins=time_bins,
                )[0]
            )
        
        behavior.at[trial, "trajectory"] = raw_position.iloc[
            start_idx_list[trial] : end_idx_list[trial]
        ][["time", "x", "y"]].values
        behavior.at[trial, "trial_start_position"] = raw_position.iloc[
            trial_start_idx_list[trial]
        ][["x", "y"]].values
        behavior.at[trial, "trial_end_position"] = raw_position.iloc[
            trial_end_idx_list[trial]
        ][["x", "y"]].values
    spikes = spikes.to(
        torch.float32
    )  # (n_trials, n_time_bins, n_neurons)
    return spikes, behavior
# Out:
# ⠸ Connecting to=hpc_cpu... status=CONNECTED

# %%
spikes, behavior = load_data()
print(spikes.shape)
behavior.head()
# Out:
# ⠸ Connecting to=hpc_cpu... status=CONNECTED
# torch.Size([54, 750, 18])
#    trial_start_time  trial_end_time     rule    outcome choice light_position  \
# 0         1968759.3       1971595.3  go dark  incorrect   left           left
# 1         1993249.2       1996285.4  go dark  incorrect   left           left
# 2         2005927.9       2014169.0  go dark  incorrect   left           left
# 3         2023611.3       2033854.4  go dark    correct   left          right
# 4         2093010.5       2096880.8  go dark  incorrect   left           left
#
#                                           trajectory trial_start_position  \
# 0  [[1963787.9, 173.2, 187.2], [1963821.3, 173.0,...       [169.4, 134.2]
# 1  [[1988277.8, 155.8, 163.1], [1988311.2, 155.9,...       [168.1, 135.9]
# 2  [[2000956.5, 147.1, 92.3], [2000989.9, 146.5, ...       [176.1, 204.8]
# 3  [[2018639.9, 119.3, 81.6], [2018673.3, 118.8, ...       [182.4, 184.7]
# 4  [[2088039.1, 173.8, 192.2], [2088072.5, 174.6,...       [152.9, 129.2]
#
#   trial_end_position
# 0      [257.1, 49.1]
# 1      [254.9, 47.9]
# 2      [254.0, 46.1]
# 3      [255.8, 46.2]
# 4      [255.1, 44.4]

# %% [markdown]
# ## 2 Configure the HMM-GLM

# %% [markdown]
# Generated spike count of neuron $n$ at time $t$
# $$ x_{t,n} \sim \mathcal{P}(f_{t,n}) $$
#
# Firing rate of neuron $n$ at time $t$
# $$ f_{t,n} = \operatorname{softplus}\left(b_{z_t, n} + \sum_{n'=1}^N \underbrace{\left(\sum_{k=1}^K x_{t-k,n'} \cdot \phi_{z_t,n\gets n',k}\right)}_{\text{convolved history, $n\gets n'$, state $z_t$}}\right) $$
# * $z_t\in\{1,\dots,S\}$: HMM state at time $t$
# * $b_{s,n}$: bias (background intensity) of neuron $n$ in state $s\in\{1,\dots,S\}$
# * $\phi_{s,n\gets n',:} \in \mathbb{R}^K$: temporal convolution kernel corresponds to the influence from neuron $n'$ to neuron $n$ if in state $s$.

# %%
n_trials, n_time_bins, n_neurons = spikes.shape
n_states = 4
kernel_size = 5
# Out:
# ⠸ Connecting to=hpc_cpu... status=CONNECTED

# %%
torch.manual_seed(0)

decoder_hmmglm = naive.HMMGLM(
    n_states=n_states,
    n_neurons=n_neurons,
    kernel_size=kernel_size,
    activation="softplus",  # or "sigmoid", etc
)
# Out:
# ⠸ Connecting to=hpc_cpu... status=CONNECTED

# %% [markdown]
# ## 3 Train HMM-GLM

# %%
def train_hmmglm(
    decoder: naive.HMMGLM,
    optimizer: torch.optim.Optimizer,
    spikes: torch.FloatTensor,
    n_epochs: int = 100,
    forward_backward_every_n_epochs: int = 1,
    print_freq: int = 1,
) -> torch.FloatTensor:
    
    n_trials, n_time_bins, n_neurons = spikes.shape

    gamma_list = [None for _ in range(n_trials)]
    xi_list = [None for _ in range(n_trials)]

    df_log = pd.DataFrame(index=range(n_epochs), columns=["loss", "conditional_log_prob", "expected_log_prob"])

    for epoch in range(n_epochs):
        for trial in range(n_trials):
            x = spikes[trial]  # (n_time_bins, n_neurons)
            x_pred_mean = decoder(x)  # (n_states, n_time_bins, n_neurons)
            emission_log_prob = distributions.poisson_log_likelihood(
                x[None, :, :], x_pred_mean
            ).sum(dim=-1).T  # (n_time_bins, n_states)

            if epoch % forward_backward_every_n_epochs == 0:
                gamma_list[trial], xi_list[trial] = inference.forward_backward(
                    emission_log_prob, decoder.transition_matrix, algorithm="logsumexp"
                )
            
            expected_log_prob = (
                    inference.baum_welch(
                    emission_log_prob,
                    decoder.transition_matrix,
                    gamma_list[trial],
                    xi_list[trial],
                )
                / x.shape[0]
            )

            loss = -expected_log_prob
                
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            df_log.at[epoch, "loss"] = loss.item() / n_trials
            df_log.at[epoch, "conditional_log_prob"] = (
                emission_log_prob[torch.arange(n_time_bins), gamma_list[trial].argmax(dim=-1)].sum().item() / n_trials
            )
            df_log.at[epoch, "expected_log_prob"] = expected_log_prob.item() / n_trials
        
        if epoch % print_freq == 0:
            print(epoch, df_log.loc[epoch], flush=True)
    
    return df_log
# Out:
# ⠹ Connecting to=hpc_cpu... status=CONNECTED

# %%
optimizer = torch.optim.AdamW(
    decoder_hmmglm.parameters(),
    lr=5e-3,
)
n_epochs = 100
forward_backward_every_n_epochs = 4
# Out:
# ⠸ Connecting to=hpc_cpu... status=CONNECTED

# %%
df_log = train_hmmglm(
    decoder_hmmglm,
    optimizer,
    spikes,
    n_epochs=n_epochs,
    forward_backward_every_n_epochs=forward_backward_every_n_epochs,
    print_freq=1,
)
# Out:
# ⠸ Connecting to=hpc_cpu... status=CONNECTED
# 0 loss                     0.088441
# conditional_log_prob   -64.268166
# expected_log_prob       -0.088441
# Name: 0, dtype: object
# 1 loss                     0.087851
# conditional_log_prob   -63.847711
# expected_log_prob       -0.087851
# Name: 1, dtype: object
# 2 loss                     0.087508
# conditional_log_prob   -63.594785
# expected_log_prob       -0.087508
# Name: 2, dtype: object
# 3 loss                     0.087256
# conditional_log_prob   -63.404044
# expected_log_prob       -0.087256
# Name: 3, dtype: object
# 4 loss                     0.087145
# conditional_log_prob   -63.142221
# expected_log_prob       -0.087145
# Name: 4, dtype: object
# 5 loss                     0.086948
# conditional_log_prob   -63.000552
# expected_log_prob       -0.086948
# Name: 5, dtype: object
# 6 loss                     0.086785
# conditional_log_prob   -62.880575
# expected_log_prob       -0.086785
# Name: 6, dtype: object
# 7 loss                     0.086645
# conditional_log_prob   -62.776955
# expected_log_prob       -0.086645
# Name: 7, dtype: object
# 8 loss                     0.086515
# conditional_log_prob   -62.508699
# expected_log_prob       -0.086515
# Name: 8, dtype: object
# 9 loss                    0.086395
# conditional_log_prob   -62.42117
# expected_log_prob      -0.086395
# Name: 9, dtype: object
# 10 loss                     0.086292
# conditional_log_prob   -62.345391
# expected_log_prob       -0.086292
# Name: 10, dtype: object
# 11 loss                     0.086201
# conditional_log_prob   -62.278885
# expected_log_prob       -0.086201
# Name: 11, dtype: object
# 12 loss                     0.08605
# conditional_log_prob   -62.18901
# expected_log_prob       -0.08605
# Name: 12, dtype: object
# 13 loss                     0.085968
# conditional_log_prob   -62.125488
# expected_log_prob       -0.085968
# Name: 13, dtype: object
# 14 loss                     0.085896
# conditional_log_prob   -62.069964
# expected_log_prob       -0.085896
# Name: 14, dtype: object
# 15 loss                     0.085831
# conditional_log_prob   -62.021064
# expected_log_prob       -0.085831
# Name: 15, dtype: object
# 16 loss                     0.085676
# conditional_log_prob   -62.023727
# expected_log_prob       -0.085676
# Name: 16, dtype: object
# 17 loss                     0.085617
# conditional_log_prob   -61.980731
# expected_log_prob       -0.085617
# Name: 17, dtype: object
# 18 loss                     0.085563
# conditional_log_prob   -61.942699
# expected_log_prob       -0.085563
# Name: 18, dtype: object
# 19 loss                     0.085515
# conditional_log_prob   -61.908823
# expected_log_prob       -0.085515
# Name: 19, dtype: object
# 20 loss                     0.085368
# conditional_log_prob   -61.991609
# expected_log_prob       -0.085368
# Name: 20, dtype: object
# 21 loss                     0.085323
# conditional_log_prob   -61.960418
# expected_log_prob       -0.085323
# Name: 21, dtype: object
# 22 loss                     0.085283
# conditional_log_prob   -61.932445
# expected_log_prob       -0.085283
# Name: 22, dtype: object
# 23 loss                     0.085246
# conditional_log_prob   -61.907276
# expected_log_prob       -0.085246
# Name: 23, dtype: object
# 24 loss                     0.085104
# conditional_log_prob   -62.060764
# expected_log_prob       -0.085104
# Name: 24, dtype: object
# 25 loss                     0.085069
# conditional_log_prob   -62.032263
# expected_log_prob       -0.085069
# Name: 25, dtype: object
# 26 loss                    0.085038
# conditional_log_prob   -62.00765
# expected_log_prob      -0.085038
# Name: 26, dtype: object
# 27 loss                     0.085009
# conditional_log_prob   -61.985853
# expected_log_prob       -0.085009
# Name: 27, dtype: object
# 28 loss                     0.084875
# conditional_log_prob   -61.985428
# expected_log_prob       -0.084875
# Name: 28, dtype: object
# 29 loss                     0.084848
# conditional_log_prob   -61.963826
# expected_log_prob       -0.084848
# Name: 29, dtype: object
# 30 loss                     0.084823
# conditional_log_prob   -61.945466
# expected_log_prob       -0.084823
# Name: 30, dtype: object
# 31 loss                    0.084801
# conditional_log_prob   -61.92919
# expected_log_prob      -0.084801
# Name: 31, dtype: object
# 32 loss                     0.084686
# conditional_log_prob   -61.872369
# expected_log_prob       -0.084686
# Name: 32, dtype: object
# 33 loss                     0.084664
# conditional_log_prob   -61.856278
# expected_log_prob       -0.084664
# Name: 33, dtype: object
# 34 loss                     0.084646
# conditional_log_prob   -61.842498
# expected_log_prob       -0.084646
# Name: 34, dtype: object
# 35 loss                     0.084629
# conditional_log_prob   -61.830132
# expected_log_prob       -0.084629
# Name: 35, dtype: object
# 36 loss                     0.084541
# conditional_log_prob   -61.778117
# expected_log_prob       -0.084541
# Name: 36, dtype: object
# 37 loss                     0.084525
# conditional_log_prob   -61.767556
# expected_log_prob       -0.084525
# Name: 37, dtype: object
# 38 loss                      0.08451
# conditional_log_prob   -61.758106
# expected_log_prob        -0.08451
# Name: 38, dtype: object
# 39 loss                     0.084497
# conditional_log_prob   -61.749344
# expected_log_prob       -0.084497
# Name: 39, dtype: object
# 40 loss                     0.084431
# conditional_log_prob   -61.821343
# expected_log_prob       -0.084431
# Name: 40, dtype: object
# 41 loss                     0.084418
# conditional_log_prob   -61.810922
# expected_log_prob       -0.084418
# Name: 41, dtype: object
# 42 loss                     0.084406
# conditional_log_prob   -61.801744
# expected_log_prob       -0.084406
# Name: 42, dtype: object
# 43 loss                    0.084395
# conditional_log_prob   -61.79343
# expected_log_prob      -0.084395
# Name: 43, dtype: object
# 44 loss                     0.084339
# conditional_log_prob   -61.791838
# expected_log_prob       -0.084339
# Name: 44, dtype: object
# 45 loss                     0.084327
# conditional_log_prob   -61.781164
# expected_log_prob       -0.084327
# Name: 45, dtype: object
# 46 loss                     0.084316
# conditional_log_prob   -61.772018
# expected_log_prob       -0.084316
# Name: 46, dtype: object
# 47 loss                     0.084306
# conditional_log_prob   -61.763898
# expected_log_prob       -0.084306
# Name: 47, dtype: object
# 48 loss                     0.084252
# conditional_log_prob   -61.745194
# expected_log_prob       -0.084252
# Name: 48, dtype: object
# 49 loss                     0.084239
# conditional_log_prob   -61.735239
# expected_log_prob       -0.084239
# Name: 49, dtype: object
# 50 loss                     0.084229
# conditional_log_prob   -61.726942
# expected_log_prob       -0.084229
# Name: 50, dtype: object
# 51 loss                      0.08422
# conditional_log_prob   -61.719736
# expected_log_prob        -0.08422
# Name: 51, dtype: object
# 52 loss                     0.084165
# conditional_log_prob   -61.737779
# expected_log_prob       -0.084165
# Name: 52, dtype: object
# 53 loss                     0.084154
# conditional_log_prob   -61.729899
# expected_log_prob       -0.084154
# Name: 53, dtype: object
# 54 loss                     0.084144
# conditional_log_prob   -61.723325
# expected_log_prob       -0.084144
# Name: 54, dtype: object
# 55 loss                     0.084136
# conditional_log_prob   -61.717615
# expected_log_prob       -0.084136
# Name: 55, dtype: object
# 56 loss                     0.084078
# conditional_log_prob   -61.771774
# expected_log_prob       -0.084078
# Name: 56, dtype: object
# 57 loss                     0.084066
# conditional_log_prob   -61.760462
# expected_log_prob       -0.084066
# Name: 57, dtype: object
# 58 loss                     0.084057
# conditional_log_prob   -61.751121
# expected_log_prob       -0.084057
# Name: 58, dtype: object
# 59 loss                     0.084049
# conditional_log_prob   -61.743191
# expected_log_prob       -0.084049
# Name: 59, dtype: object
# 60 loss                     0.083989
# conditional_log_prob   -61.778275
# expected_log_prob       -0.083989
# Name: 60, dtype: object
# 61 loss                     0.083978
# conditional_log_prob   -61.768017
# expected_log_prob       -0.083978
# Name: 61, dtype: object
# 62 loss                    0.083968
# conditional_log_prob   -61.75949
# expected_log_prob      -0.083968
# Name: 62, dtype: object
# 63 loss                      0.08396
# conditional_log_prob   -61.752224
# expected_log_prob        -0.08396
# Name: 63, dtype: object
# 64 loss                     0.083911
# conditional_log_prob   -61.745235
# expected_log_prob       -0.083911
# Name: 64, dtype: object
# 65 loss                     0.083901
# conditional_log_prob   -61.737278
# expected_log_prob       -0.083901
# Name: 65, dtype: object
# 66 loss                     0.083893
# conditional_log_prob   -61.730591
# expected_log_prob       -0.083893
# Name: 66, dtype: object
# 67 loss                     0.083886
# conditional_log_prob   -61.724826
# expected_log_prob       -0.083886
# Name: 67, dtype: object
# 68 loss                     0.083855
# conditional_log_prob   -61.742414
# expected_log_prob       -0.083855
# Name: 68, dtype: object
# 69 loss                     0.083847
# conditional_log_prob   -61.736292
# expected_log_prob       -0.083847
# Name: 69, dtype: object
# 70 loss                     0.083841
# conditional_log_prob   -61.731066
# expected_log_prob       -0.083841
# Name: 70, dtype: object
# 71 loss                     0.083835
# conditional_log_prob   -61.726522
# expected_log_prob       -0.083835
# Name: 71, dtype: object
# 72 loss                     0.083818
# conditional_log_prob   -61.715603
# expected_log_prob       -0.083818
# Name: 72, dtype: object
# 73 loss                     0.083812
# conditional_log_prob   -61.711263
# expected_log_prob       -0.083812
# Name: 73, dtype: object
# 74 loss                     0.083807
# conditional_log_prob   -61.707452
# expected_log_prob       -0.083807
# Name: 74, dtype: object
# 75 loss                     0.083803
# conditional_log_prob   -61.704093
# expected_log_prob       -0.083803
# Name: 75, dtype: object
# 76 loss                     0.083794
# conditional_log_prob   -61.697401
# expected_log_prob       -0.083794
# Name: 76, dtype: object
# 77 loss                      0.08379
# conditional_log_prob   -61.694458
# expected_log_prob        -0.08379
# Name: 77, dtype: object
# 78 loss                     0.083786
# conditional_log_prob   -61.691727
# expected_log_prob       -0.083786
# Name: 78, dtype: object
# 79 loss                     0.083783
# conditional_log_prob   -61.689263
# expected_log_prob       -0.083783
# Name: 79, dtype: object
# 80 loss                     0.083779
# conditional_log_prob   -61.689887
# expected_log_prob       -0.083779
# Name: 80, dtype: object
# 81 loss                    0.083776
# conditional_log_prob   -61.68797
# expected_log_prob      -0.083776
# Name: 81, dtype: object
# 82 loss                    0.083773
# conditional_log_prob   -61.68604
# expected_log_prob      -0.083773
# Name: 82, dtype: object
# 83 loss                     0.083771
# conditional_log_prob   -61.684254
# expected_log_prob       -0.083771
# Name: 83, dtype: object
# 84 loss                      0.08377
# conditional_log_prob   -61.685646
# expected_log_prob        -0.08377
# Name: 84, dtype: object
# 85 loss                     0.083768
# conditional_log_prob   -61.684299
# expected_log_prob       -0.083768
# Name: 85, dtype: object
# 86 loss                     0.083766
# conditional_log_prob   -61.682852
# expected_log_prob       -0.083766
# Name: 86, dtype: object
# 87 loss                     0.083764
# conditional_log_prob   -61.681491
# expected_log_prob       -0.083764
# Name: 87, dtype: object
# 88 loss                     0.083766
# conditional_log_prob   -61.693906
# expected_log_prob       -0.083766
# Name: 88, dtype: object
# 89 loss                     0.083765
# conditional_log_prob   -61.692835
# expected_log_prob       -0.083765
# Name: 89, dtype: object
# 90 loss                     0.083763
# conditional_log_prob   -61.691632
# expected_log_prob       -0.083763
# Name: 90, dtype: object
# 91 loss                     0.083761
# conditional_log_prob   -61.690493
# expected_log_prob       -0.083761
# Name: 91, dtype: object
# 92 loss                     0.083765
# conditional_log_prob   -61.693115
# expected_log_prob       -0.083765
# Name: 92, dtype: object
# 93 loss                     0.083764
# conditional_log_prob   -61.692509
# expected_log_prob       -0.083764
# Name: 93, dtype: object
# 94 loss                     0.083763
# conditional_log_prob   -61.691646
# expected_log_prob       -0.083763
# Name: 94, dtype: object
# 95 loss                     0.083762
# conditional_log_prob   -61.690846
# expected_log_prob       -0.083762
# Name: 95, dtype: object
# 96 loss                     0.083767
# conditional_log_prob   -61.688779
# expected_log_prob       -0.083767
# Name: 96, dtype: object
# 97 loss                     0.083767
# conditional_log_prob   -61.688581
# expected_log_prob       -0.083767
# Name: 97, dtype: object
# 98 loss                     0.083765
# conditional_log_prob   -61.687925
# expected_log_prob       -0.083765
# Name: 98, dtype: object
# 99 loss                    0.083765
# conditional_log_prob   -61.68741
# expected_log_prob      -0.083765
# Name: 99, dtype: object

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3), layout="constrained")
axs[0].plot(df_log["loss"])
axs[0].set_title("Loss")
axs[1].plot(df_log["conditional_log_prob"])
axs[1].set_title("Conditional log prob")
axs[2].plot(df_log["expected_log_prob"])
axs[2].set_title("Expected log prob")
fig.supxlabel("Epoch")
# Out:
# ⠸ Connecting to=hpc_cpu... status=CONNECTED
# Text(0.5, 0.01, 'Epoch')

# %% [markdown]
# ## 4 Check and visualize the result

# %%
with torch.no_grad():
    decoder_hmmglm.eval()
    weight = decoder_hmmglm.conv.weight.sum(dim=-1).reshape(n_states, n_neurons, n_neurons)

    fig, axs = plt.subplots(1, n_states, figsize=(12, 4), layout="constrained")
    for state in range(n_states):
        ax = axs[state]
        ax.matshow(weight[state], vmin=-5, vmax=5, cmap="seismic")
        ax.set_title(f"State {state}")
        ax.set(xticks=[], yticks=[])
# Out:
# ⠹ Connecting to=hpc_cpu... status=CONNECTED

# %%
def plot_frame(ax):
    transform = np.array([[-1 / 2, np.sqrt(3) / 2], [-np.sqrt(3) / 2, -1 / 2]])
    radius = 40
    theta = 210 / 360 * 2 * np.pi
    start = np.array([radius * np.cos(theta), radius * np.sin(theta)])
    arm_length = 125
    theta = 330 / 360 * 2 * np.pi
    end = np.array([radius * np.cos(theta), radius * np.sin(theta)])
    one_arm = np.array(
        [
            [start[0], start[0], end[0], end[0]],
            [start[1], start[1] - arm_length, end[1] - arm_length, end[1]],
        ]
    )
    ax.plot(one_arm[0], one_arm[1], "k")
    one_arm = transform @ one_arm
    ax.plot(one_arm[0], one_arm[1], "k")
    one_arm = transform @ one_arm
    ax.plot(one_arm[0], one_arm[1], "k")

    # ax.text(0, -160, "root", fontsize=15, va="center", ha="center")
    ax.set_xlim(-160, 160)
    ax.set_ylim(-190, 130)
    ax.axis("off")
    ax.set_aspect("equal")


def plot_states(ax, behavior_ser, inferred_states, markersize: int = 6):
    trajectory_time = behavior_ser["trajectory"][:, 0]
    ax.matshow(inferred_states[None, :], vmin=0, vmax=9, cmap="tab10", aspect="auto")
    ax.set(xticks=[], yticks=[])

    if behavior_ser["outcome"] == "correct":
        marker = "*k"
    else:
        marker = "sk"

    trial_start_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_start_time"])
        / len(trajectory_time)
        * len(inferred_states)
    )
    trial_end_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_end_time"])
        / len(trajectory_time)
        * len(inferred_states)
    )
    ax.plot(trial_start_idx, 0, ">k", markersize=markersize)
    ax.plot(trial_end_idx, 0, marker, markersize=markersize)


def plot_soft_states(ax, behavior_ser, gamma, markersize: int = 6):
    trajectory_time = behavior_ser["trajectory"][:, 0]
    n_states = gamma.shape[1]
    for state in range(n_states):
        ax.matshow(
            state * np.ones((1, gamma.shape[0])),
            vmin=0,
            vmax=9,
            cmap="tab10",
            aspect="auto",
            alpha=gamma[None, :, state],
        )
    ax.set(xticks=[], yticks=[])

    if behavior_ser["outcome"] == "correct":
        marker = "*k"
    else:
        marker = "sk"

    trial_start_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_start_time"])
        / len(trajectory_time)
        * len(gamma)
    )
    trial_end_idx = (
        np.searchsorted(trajectory_time, behavior_ser["trial_end_time"])
        / len(trajectory_time)
        * len(gamma)
    )
    ax.plot(trial_start_idx, 0, ">k", markersize=markersize)
    ax.plot(trial_end_idx, 0, marker, markersize=markersize)


def plot_trajectory(
    ax, behavior_ser: pd.Series, inferred_states: torch.Tensor, n_points: int | None = None, truncate: tuple[int|None, int|None] = (0, -1), markersize: int = 10
):
    theta = 185 / 360 * 2 * np.pi
    transform = np.array(
        [[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]]
    )
    translation = np.array([155, 122])
    trial_start_position = behavior_ser["trial_start_position"]
    trial_start_position = transform @ trial_start_position + translation
    ax.plot(
        trial_start_position[0],
        trial_start_position[1],
        ">k",
        markersize=markersize,
    )
    if behavior_ser["outcome"] == "correct":
        marker = "*k"
    else:
        marker = "sk"
    if behavior_ser["light_position"] == "right":
        ax.add_patch(Circle((140, 90), 10, fc="gold", edgecolor="black"))
        ax.add_patch(Wedge((140, 80), 5, 180, 360, fc="none", edgecolor="black"))
    else:
        ax.add_patch(Circle((-140, 90), 10, fc="gold", edgecolor="black"))
        ax.add_patch(Wedge((-140, 80), 6, 180, 360, fc="none", edgecolor="black"))
    trial_end_position = behavior_ser["trial_end_position"]
    trial_end_position = transform @ trial_end_position + translation
    ax.plot(
        trial_end_position[0],
        trial_end_position[1],
        marker,
        markersize=markersize,
    )
    ax.text(0, 90, f"{behavior_ser['rule']}", fontsize=15, ha="center", va="center")

    trajectory = behavior_ser["trajectory"][:, 1:]

    if n_points is None:
        n_points = min(len(trajectory), len(inferred_states))
    trajectory = trajectory[np.linspace(0, len(trajectory) - 1, n_points, dtype=int)]
    trajectory = trajectory @ transform.T + translation
    inferred_states = inferred_states[
        np.linspace(0, len(inferred_states) - 1, n_points, dtype=int)
    ]
    ax.scatter(
        trajectory[truncate[0]:truncate[1], 0],
        trajectory[truncate[0]:truncate[1], 1],
        c=inferred_states[truncate[0]:truncate[1]],
        vmin=0,
        vmax=9,
        cmap="tab10",
        s=1,
        zorder=10,
    )
# Out:
# ⠸ Connecting to=hpc_cpu... status=CONNECTED

# %%
n_rows = (n_trials - 1) // 5 + 1
n_points = 450
fig, axs = plt.subplots(n_rows, 5, figsize=(12, 2.2 * n_rows), layout="constrained")
axs = axs.flatten()

gamma_list = [None for _ in range(n_trials)]
inferred_states_list = [None for _ in range(n_trials)]

with torch.no_grad():
    for trial in range(n_trials):
    # for trial in range(5):
        x = spikes[trial]  # (n_time_bins, n_neurons)
        x_pred_mean = decoder_hmmglm(x)  # (n_states, n_time_bins, n_neurons)
        emission_log_prob = distributions.poisson_log_likelihood(
            x[None, :, :], x_pred_mean
        ).sum(dim=-1).T  # (n_time_bins, n_states)

        gamma_list[trial], _ = inference.forward_backward(
            emission_log_prob, decoder_hmmglm.transition_matrix, algorithm="logsumexp"
        )
        inferred_states_list[trial] = inference.viterbi(
            emission_log_prob, decoder_hmmglm.transition_matrix
        )
        ax = axs[trial]
        plot_frame(ax)
        plot_trajectory(ax, behavior.loc[trial], inferred_states_list[trial], n_points=n_points, truncate=(150, -1))
        ax_divider = make_axes_locatable(ax)
        ax_states = ax_divider.append_axes("top", size="20%", pad=0)
        plot_soft_states(ax_states, behavior.loc[trial], gamma_list[trial])
        # plot_states(ax_states, behavior.loc[trial], inferred_states_list[trial])


    for trial in range(n_trials, len(axs)):
        axs[trial].axis("off")
# Out:
# ⠹ Connecting to=hpc_cpu... status=CONNECTED

# %%
# %stop_runtime hpc_cpu
# %switch_runtime local
# Out:
# Terminated runtime=hpc_cpu. state={'experimentId': 'CS_Agent_7639b68e-f9e4-4d03-8abb-5b70a8c23596', 'terminated': True}
# Switched to runtime=local.
